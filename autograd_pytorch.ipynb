# %%
def dy_dx(x):
    return 2*x

# %%
dy_dx(2)
# Out:
# 4

# %%
import torch

# %%
def nested_fun(x):
    return 2*x*torch.cos(x**2)

# %%
a=torch.tensor(2.0)
nested_fun(a)
# Out:
# tensor(-2.6146)

# %%
X=torch.tensor(1.0,requires_grad=True)

# %%
X
# Out:
# tensor(1., requires_grad=True)

# %%
y=X**2

# %%
y
# Out:
# tensor(1., grad_fn=<PowBackward0>)

# %%
X.backward()

# %%
X.grad
# Out:
# tensor(1.)

# %% [markdown]
# ## Second Function

# %%
X=torch.tensor(1.0,requires_grad=True)

# %%
X
# Out:
# tensor(1., requires_grad=True)

# %%
y=X**2
y
# Out:
# tensor(1., grad_fn=<PowBackward0>)

# %%
z=torch.sin(y)
z
# Out:
# tensor(0.8415, grad_fn=<SinBackward0>)

# %% [markdown]
# ## Manual Process

# %%
X=torch.tensor(2.0)
y=torch.tensor(0.0)

w=torch.tensor(1.0)
b=torch.tensor(0.0)

# %%
# BCE
def binary_cross_entropy_loss(prediction, target):

    # Small value to avoid numerical problems
    # Why? Because log(0) is undefined (-infinity)
    # So we never want prediction to become exactly 0 or exactly 1
    epsilon = 1e-8

    # Clamp means: force values to stay inside a safe range
    # If prediction < epsilon → set it to epsilon
    # If prediction > (1 - epsilon) → set it to (1 - epsilon)
    # This prevents log(0) when computing:
    # log(prediction) or log(1 - prediction)

    prediction = torch.clamp(prediction, epsilon, 1 - epsilon) # torch.clamp(x, min_value, max_value)

    # BCE formula:
    # target * log(prediction)     → used when target = 1
    # (1 - target) * log(1 - prediction) → used when target = 0
    # Negative sign makes loss positive

    loss = -(target * torch.log(prediction) +
             (1 - target) * torch.log(1 - prediction))

    return loss

# %%
# Forward pass
z = w * X + b  # Weighted sum (linear part)
y_pred = torch.sigmoid(z)  # Predicted probability

# Compute binary cross-entropy loss
loss = binary_cross_entropy_loss(y_pred, y)

# %%
loss
# Out:
# tensor(2.1269)

# %%
#derivative
#1
dloss_by_pred=(y_pred-y)/(y_pred*(1-y_pred))
#2
dy_pred_dz=y_pred*(1-y_pred)

dz_dw=X
dz_db=1

dL_dw=dloss_by_pred*dy_pred_dz*dz_dw
dL_db=dloss_by_pred*dy_pred_dz*dz_db

# %%
dL_dw
# Out:
# tensor(1.7616)

# %%
dL_db
# Out:
# tensor(0.8808)

# %% [markdown]
# ### Using autograd

# %%
X=torch.tensor(2.0)
y=torch.tensor(0.0)

w=torch.tensor(1.0,requires_grad=True)
b=torch.tensor(0.0,requires_grad=True)

# %%
z=w*X+b

# %%
z
# Out:
# tensor(2., grad_fn=<AddBackward0>)

# %%
y_pred=torch.sigmoid(z)

# %%
y_pred
# Out:
# tensor(0.8808, grad_fn=<SigmoidBackward0>)

# %%
loss=binary_cross_entropy_loss(y_pred,y)

# %%
loss
# Out:
# tensor(2.1269, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
w.grad
# Out:
# tensor(1.7616)

# %% [markdown]
# # Using multiple value

# %%
X=torch.tensor([1.0,2.0,3.0],requires_grad=True)

# %%
X
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y=(X**2).mean()

# %%
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
X.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %%
#Option 1
X.grad.zero_()
# Out:
# tensor([0., 0., 0.])

# %%
#Option 2
X.requires_grad_(False)
# Out:
# tensor([1., 2., 3.])

# %%
X
# Out:
# tensor([1., 2., 3.])

# %%
y=X**2
y
# Out:
# tensor([1., 4., 9.])

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 y.backward()
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\_tensor.py:630, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     620 if has_torch_function_unary(self):
#     621     return handle_torch_function(
#     622         Tensor.backward,
#     623         (self,),
#    (...)
#     628         inputs=inputs,
#     629     )
# --> 630 torch.autograd.backward(
#     631     self, gradient, retain_graph, create_graph, inputs=inputs
#     632 )
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\autograd\__init__.py:364, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     359     retain_graph = create_graph
#     361 # The reason we repeat the same comment below is that
#     362 # some Python versions print out the first line of a multi-line function
#     363 # calls in the traceback and some print out the last line
# --> 364 _engine_run_backward(
#     365     tensors,
#     366     grad_tensors_,
#     367     retain_graph,
#     368     create_graph,
#     369     inputs_tuple,
#     370     allow_unreachable=True,
#     371     accumulate_grad=True,
#     372 )
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\autograd\graph.py:865, in _engine_run_backward(t_outputs, *args, **kwargs)
#     863     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     864 try:
# --> 865     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     866         t_outputs, *args, **kwargs
#     867     )  # Calls into the C++ engine to run the backward pass
#     868 finally:
#     869     if attach_logging_hooks:
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn

# %%
x = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
z = x.detach()
z
# Out:
# tensor(2.)

# %%
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x ** 2

# %%
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y1 = z ** 2
y1
# Out:
# tensor(4.)

# %%
y.backward()

# %%
y1.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 y1.backward()
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\_tensor.py:630, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     620 if has_torch_function_unary(self):
#     621     return handle_torch_function(
#     622         Tensor.backward,
#     623         (self,),
#    (...)
#     628         inputs=inputs,
#     629     )
# --> 630 torch.autograd.backward(
#     631     self, gradient, retain_graph, create_graph, inputs=inputs
#     632 )
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\autograd\__init__.py:364, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     359     retain_graph = create_graph
#     361 # The reason we repeat the same comment below is that
#     362 # some Python versions print out the first line of a multi-line function
#     363 # calls in the traceback and some print out the last line
# --> 364 _engine_run_backward(
#     365     tensors,
#     366     grad_tensors_,
#     367     retain_graph,
#     368     create_graph,
#     369     inputs_tuple,
#     370     allow_unreachable=True,
#     371     accumulate_grad=True,
#     372 )
#
# File c:\Users\User\anaconda3\Lib\site-packages\torch\autograd\graph.py:865, in _engine_run_backward(t_outputs, *args, **kwargs)
#     863     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     864 try:
# --> 865     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     866         t_outputs, *args, **kwargs
#     867     )  # Calls into the C++ engine to run the backward pass
#     868 finally:
#     869     if attach_logging_hooks:
#
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn

# %%
x = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x ** 2

# %%
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()
