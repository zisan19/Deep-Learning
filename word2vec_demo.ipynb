# %%
pip install gensim
# Out:
# ...
#   Using cached gensim-4.4.0-cp313-cp313-win_amd64.whl.metadata (8.6 kB)
# ...
# Using cached gensim-4.4.0-cp313-cp313-win_amd64.whl (24.4 MB)
# ...
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.3/36.6 MB ? eta -:--:--
#     --------------------------------------- 0.8/36.6 MB 2.4 MB/s eta 0:00:15
#    - -------------------------------------- 1.3/36.6 MB 2.6 MB/s eta 0:00:14
#    -- ------------------------------------- 2.4/36.6 MB 3.2 MB/s eta 0:00:11
#    --- ------------------------------------ 3.4/36.6 MB 3.5 MB/s eta 0:00:10
#    ---- ----------------------------------- 4.5/36.6 MB 3.7 MB/s eta 0:00:09
#    ------ --------------------------------- 5.5/36.6 MB 4.0 MB/s eta 0:00:08
#    ------- -------------------------------- 7.1/36.6 MB 4.3 MB/s eta 0:00:07
#    --------- ------------------------------ 8.4/36.6 MB 4.5 MB/s eta 0:00:07
#    ---------- ----------------------------- 9.7/36.6 MB 4.8 MB/s eta 0:00:06
# ...

# %%
pip install wget
# Out:
# ...
#   Using cached wget-3.2-py3-none-any.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -U gensim
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import gensim.downloader as api
import torch
import torch.nn as nn

# 1. Automatically download, extract, and load the 300d Google News model
print("Loading Google News Word2Vec...")
word2vec_model=api.load('word2vec-google-news-300')
# Out:
# Loading Google News Word2Vec...

# %%
# 1. Download the pre-trained weights from a working Hugging Face mirror

# !wget -c -O GoogleNews-vectors-negative300.bin.gz "https://huggingface.co/rajnishrajput12/finber/resolve/main/GoogleNews-vectors-negative300.bin.gz"

import gensim
from gensim.models import KeyedVectors
import warnings
warnings.filterwarnings('ignore') # Hides the Gensim vstack FutureWarning from your output
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# 2. Load the embeddings (limiting to 500,000 words to save RAM)

print("Loading Word2Vec model into memory...")

model = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary=True, limit=500000)
print("Model loaded successfully!\n")
print("-" * 50)
# Out:
# Loading Word2Vec model into memory...
# Model loaded successfully!
#
# --------------------------------------------------

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\User\OneDrive\Desktop\Deep learning

# %%
# 2. Load the embeddings (limiting to 500,000 words to save RAM)

print("Loading Word2Vec model into memory...")

model = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary=True, limit=500000)
print("Model loaded successfully!\n")
print("-" * 50)
# Out:
# Loading Word2Vec model into memory...
# Model loaded successfully!
#
# --------------------------------------------------

# %%
# 3. Extracting the vector array for a specific word
print("Vector array for 'cricket' (first 10 dimensions):")

print(model['king'][:10])
# Out:
# Vector array for 'cricket' (first 10 dimensions):
# [ 0.12597656  0.02978516  0.00860596  0.13964844 -0.02563477 -0.03613281
#   0.11181641 -0.19824219  0.05126953  0.36328125]

# %%
model['king']
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
temp = model['king']
temp.shape
# Out:
# (300,)

# %%
#  Extracting the vector array for a specific word
print("Vector array for 'cricket' (first 10 dimensions):")

print(model['Bangladesh'][:10])
# Out:
# Vector array for 'cricket' (first 10 dimensions):
# [-0.22753906  0.08789062  0.00386047  0.12207031 -0.13769531 -0.03442383
#  -0.07128906 -0.23632812 -0.29882812 -0.01086426]

# %%
# 4. Semantic Similarity (Most Similar)

print("\nMost similar to 'man':")
for word, score in model.most_similar('man', topn=5):
    print(f" - {word}: {score:.4f}")
# Out:
# Most similar to 'man':
#  - woman: 0.7664
#  - boy: 0.6825
#  - teenager: 0.6587
#  - teenage_girl: 0.6148
#  - girl: 0.5922

# %%
# . Semantic Similarity (Most Similar)

print("\nMost similar to 'man':")
for word, score in model.most_similar('Bangladesh', topn=5):
    print(f" - {word}: {score:.4f}")
# Out:
# Most similar to 'man':
#  - Bangaldesh: 0.7589
#  - Sri_Lanka: 0.7444
#  - Bangladeshi: 0.7187
#  - Dhaka: 0.7110
#  - Pakistan: 0.7074

# %%
print("\nMost similar to 'facebook':")
for word, score in model.most_similar('facebook', topn=5):
    print(f" - {word}: {score:.4f}")
# Out:
# Most similar to 'facebook':
#  - Facebook: 0.7564
#  - FaceBook: 0.7077
#  - twitter: 0.6989
#  - myspace: 0.6942
#  - Twitter: 0.6642

# %%
model.most_similar("Football")
# Out:
# [('Soccer', 0.7229189872741699),
#  ('football', 0.712483286857605),
#  ('Basketball', 0.6591217517852783),
#  ('Football_League', 0.6160993576049805),
#  ('Sports', 0.6069926619529724),
#  ('Baseball', 0.5977754592895508),
#  ('Hockey', 0.5818884968757629),
#  ('FA', 0.5659570693969727),
#  ('Rugby', 0.5638055801391602),
#  ('Volleyball', 0.5597699284553528)]

# %%
# 5. Direct Cosine Similarity Scoring

print("\nSimilarity between 'man' and 'woman':", model.similarity('man', 'woman'))
print("Similarity between 'man' and 'PHP':", model.similarity('man', 'PHP'))
# Out:
# Similarity between 'man' and 'woman': 0.76640123
# Similarity between 'man' and 'PHP': -0.032995153

# %%
# 6. Outlier Detection
print("\nDoesn't match ['PHP', 'java', 'monkey']:")
print(" ->", model.doesnt_match(['PHP', 'java', 'monkey']))
# Out:
# Doesn't match ['PHP', 'java', 'monkey']:
#  -> monkey

# %%
# 7. Deep Semantic Vector Math (Analogies)
# king - man + woman = ?

print("\nAnalogy: king - man + woman = ")

vec_king = model['king'] - model['man'] + model['woman']

for word, score in model.most_similar([vec_king], topn=3):
    print(f" - {word}: {score:.4f}")
# Out:
# Analogy: king - man + woman =
#  - king: 0.8449
#  - queen: 0.7301
#  - monarch: 0.6455
