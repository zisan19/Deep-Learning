# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

# %%
# ==========================================
# 1. Documents (Corpus)
# ==========================================
corpus = [
    "students watch youtube youtube youtube",
    "youtube watch youtube",
    "students write comments",
    "youtube write comments"
]

# %%
# create bag of words model

cv = CountVectorizer(ngram_range=(3,3))

# %%
# learn vocabulary and transfrom documnent

X = cv.fit_transform(corpus)

# %%
#show vocabulary

cv.get_feature_names_out()
# Out:
# array(['students watch youtube', 'students write comments',
#        'watch youtube youtube', 'youtube watch youtube',
#        'youtube write comments', 'youtube youtube youtube'], dtype=object)

# %%
bow_df = pd.DataFrame(
    X.toarray(),
    columns = cv.get_feature_names_out(),
    index = ["D1","D2","D3","D4"]
)
bow_df
# Out:
#     students watch youtube  students write comments  watch youtube youtube  \
# D1                       1                        0                      1
# D2                       0                        0                      0
# D3                       0                        1                      0
# D4                       0                        0                      0
#
#     youtube watch youtube  youtube write comments  youtube youtube youtube
# D1                      0                       0                        1
# D2                      1                       0                        0
# D3                      0                       0                        0
# D4                      0                       1                        0
